# %% [markdown]
# # NOTE: Put you Gemini API key in the secrets with the name "GEMINI-API-KEY" and upload the first file of gem extraction "01 - u1_Past Simple.txt"

# %%
# !pip install -qU langchain langchain_core langchain_google_genai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.7/93.7 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.3/208.3 kB 19.0 MB/s eta 0:00:00

# %%
from langchain.agents import create_agent
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.chat_models import init_chat_model
from dataclasses import dataclass

# %% [markdown]
# ## Initializing the model

# %%
# Importing gemini api key from secrets.
from google.colab import userdata

# %%
import getpass
import os

# if "GOOGLE_API_KEY" not in os.environ:
#     os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google AI API key: ")

os.environ["GOOGLE_API_KEY"] = userdata.get('GEMINI-API-KEY')
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

# %% [markdown]
# # **Main Ideas Extraction**

# %% [markdown]
# ## Setting response format

# %%
from typing import List
from pydantic import BaseModel, Field
from langchain_core.output_parsers import PydanticOutputParser

# %%
class MainIdea(BaseModel):
    name: str = Field(..., description="Main idea name")
    summary: str = Field(..., description="Detailed full-sentence summary explaining the concept, its relevance, any examples or applications, its connections to other ideas, and its role in understanding the material.")

class MainIdeas(BaseModel):
    MainIdeas: List[MainIdea]

# %% [markdown]
# ## Setting prompt

# %%
class StagePrompt(BaseModel):
    system: str
    human: str

# %%
from langchain_core.prompts import ChatPromptTemplate

# %%
extrct_prompt = StagePrompt(
    system="Instructions:\n"
    "You are an expert educator specializing in creating detailed concept maps from academic texts. Given the following excerpt from a longer document, extract the main ideas, detailed concepts, and supporting details that are critical to understanding the material.\n"
    "Focus on identifying:\n\n"
    "- Key concepts or terms introduced in the text.\n"
    "- Definitions or explanations of these concepts.\n"
    "- Relationships between concepts.\n"
    "- Any examples or applications mentioned.\n"
    "Use clear, bullet-point summaries, organized by topic. Never add any commentary\n"
    "",
    human="Here is the excerpt:\n"
    "Context:\n"
    "{context}"
)

# %%
extrct_prompt_tmplt = ChatPromptTemplate.from_messages([
    ("system", extrct_prompt.system),
    ("human", extrct_prompt.human)])

# %% [markdown]
# ## Create and run the agent.

# %%
# Create a simple chain with your llm and prompt
extrct_chain = extrct_prompt_tmplt | llm

# %%
# Reading text from a file.
with open('/content/01 - u1_Past Simple.txt', 'r') as file:
    text = file.read()

# %%
# Run the chain and parse the result into the schema
extrct_output = extrct_chain.invoke({"context": text})   # `text` was read from your file

# %%
print(extrct_output.content)
# Out:
# **Past Simple: Form**
#
# *   **Affirmative:**
#     *   Structure: Subject + Past Simple form of the verb (التصريف الثانى للفعل)
#     *   Example 1: Dalia travelled to Aswan a week ago.
#     *   Example 2: Yahya Haqqi wrote many interesting short stories.
# *   **Interrogative:**
#     *   Structure: Did + subject + infinitive?
#     *   Structure: Wh-word + did + subject + infinitive?
#     *   Example 1: Did Maher invite you to the party last Friday?
#     *   Example 2: What did you study last night?
# *   **Negative:**
#     *   Structure: Subject + didn’t + infinitive
#     *   Example: My son didn’t use mobile phones 10 years ago.
# *   **Passive:**
#     *   Structure: Object + was/were + Past Participle (P.P.)
#     *   Example: The pyramids were built by the ancient Egyptians.
#
# **Past Simple: Usage (االستخدام)**
#
# *   **Completed action in the past with a time indicator:**
#     *   Example: It rained heavily yesterday.
# *   **Completed action in the past without a time indicator (obvious past):**
#     *   Example: Graham Bell invented the telephone.
# *   **Sequence of events in the past:**
#     *   Example: Jehan wiped the table after dinner, took a shower and went to bed.
# *   **Past habits:**
#     *   Example 1: People in the past travelled on camels.
#     *   Example 2: When I was on holiday, I went to the beach every day.
#     *   **Note on 'used to':** Used for past habits, not for recent, non-habitual events.
#         *   Correct: When I was young, I used to play (played) in the street.
#         *   Incorrect: He used to go to the sports club three times last week.
#         *   Correct: He went to the sports club three times last week.
# *   **Details of events with the Present Perfect:**
#     *   Example: I’ve hurt my leg. I fell off a ladder.
# *   **Narrating stories:**
#     *   Example 1: Once, we saw a man in ... .
#     *   Example 2: He sat down and ordered a coffee.
#
# **Past Simple: Time Expressions**
#
# *   Yesterday
# *   last + duration (e.g., last month, last week)
# *   duration + ago (e.g., a week ago, 10 years ago)
# *   in + year (e.g., in 2002)
# *   the other day (منذ بضعة أيام)
#
# **Past Simple: Notes (الحــــــظ)**
#
# *   **With frequency adverbs:** Used with the same frequency adverbs as the present tense when the action was in the past.
#     *   Example: He always visited us when he was young.
# *   **With 'for':** Can be used if the action lasted for a specific period in the past.
#     *   Example: My father went to a primary school for 6 years.
# *   **Use of 'was/were':** Used when the verb is originally "to be" in affirmative, negative, and interrogative sentences.
#     *   Affirmative: I was at school last Monday.
#     *   Negative: I wasn’t at school last Monday.
#     *   Interrogative: Were you at school last Monday?
# *   **Use of 'had':** Used when the verb is originally "to have" (meaning "owned" or "possessed").
#     *   Affirmative: I had a nice bike when I was young.
#     *   Negative: In the negative, use 'didn’t have'.
#         *   Example: I didn’t have a bike when I was young.
#
# **Past Simple: Other Uses**
#
# *   **After 'I’d rather' + subject:** Expresses a preference about the present.
#     *   Example: I’d rather you went to school today.
# *   **In the 'if' clause of Conditional Type 2:** Expresses an impossible or unlikely event in the present or future (imagination/assumption).
#     *   Example: If I discovered a new planet, I’d give it my name.
# *   **After 'wish' and 'if only':** Expresses a wish or regret about the present, hoping for a different situation.
#     *   Example: I wish I lived near my school.
# *   **After 'suppose/supposing':** For assuming something unlikely or untrue.
#     *   Example: Suppose you met the president, what would you ask him to do?
# *   **After 'as if/as though':** To compare a person or thing to another, meaning "as if."
#     *   Example: Ahmed treats us as if he were a king.
# *   **For an interrupting or short action with the Past Continuous:**
#     *   Example: While Ali was climbing the ladder, he fell down.
# *   **For the second action when the first action was Past Perfect:**
#     *   Example: After he had booked the ticket, he took the train.
# *   **After 'It’s time/It’s high time':**
#     *   Example: It’s time you went to bed.

# %% [markdown]
# # **Combine & Reduce**

# %% [markdown]
# ## Combine

# %%
combine_prompt = StagePrompt(
    system="Instructions:\n"
    "You are combining multiple concept maps into a single, comprehensive summary while retaining all key ideas and details. Below are several lists of main ideas and concepts extracted from a larger document.\n"
    "Your task is to:\n\n"
    "1. Merge these lists into a single structured list, removing redundancies while keeping all unique and detailed information.\n"
    "2. Ensure all main ideas, relationships, and examples are preserved and clearly organized. Never add any commentary"
    "Respond with the consolidated and organized list of main ideas and concepts.",
    
    human="Here are the concept maps to combine:\n"
    "Context:\n"
    "{context}"
)

# %%
combine_prmpt_tmplt = ChatPromptTemplate.from_messages(
    [
        ("system", combine_prompt.system),
        ("human", combine_prompt.human)
    ]
)

# %%
combine_chain = combine_prmpt_tmplt | llm

# %%
combine_output = combine_chain.invoke({"context": extrct_output})

# %%
print(combine_output.content)
# Out:
# **Past Simple**
#
# *   **Form**
#     *   **Affirmative:**
#         *   Structure: Subject + Past Simple form of the verb (التصريف الثانى للفعل)
#         *   Example 1: Dalia travelled to Aswan a week ago.
#         *   Example 2: Yahya Haqqi wrote many interesting short stories.
#     *   **Interrogative:**
#         *   Structure: Did + subject + infinitive?
#         *   Structure: Wh-word + did + subject + infinitive?
#         *   Example 1: Did Maher invite you to the party last Friday?
#         *   Example 2: What did you study last night?
#     *   **Negative:**
#         *   Structure: Subject + didn’t + infinitive
#         *   Example: My son didn’t use mobile phones 10 years ago.
#     *   **Passive:**
#         *   Structure: Object + was/were + Past Participle (P.P.)
#         *   Example: The pyramids were built by the ancient Egyptians.
#
# *   **Usage (االستخدام)**
#     *   **Completed action in the past with a time indicator:**
#         *   Example: It rained heavily yesterday.
#     *   **Completed action in the past without a time indicator (obvious past):**
#         *   Example: Graham Bell invented the telephone.
#     *   **Sequence of events in the past:**
#         *   Example: Jehan wiped the table after dinner, took a shower and went to bed.
#     *   **Past habits:**
#         *   Example 1: People in the past travelled on camels.
#         *   Example 2: When I was on holiday, I went to the beach every day.
#         *   **Note on 'used to':** Used for past habits, not for recent, non-habitual events.
#             *   Correct: When I was young, I used to play (played) in the street.
#             *   Incorrect: He used to go to the sports club three times last week.
#             *   Correct: He went to the sports club three times last week.
#     *   **Details of events with the Present Perfect:**
#         *   Example: I’ve hurt my leg. I fell off a ladder.
#     *   **Narrating stories:**
#         *   Example 1: Once, we saw a man in ... .
#         *   Example 2: He sat down and ordered a coffee.
#
# *   **Time Expressions**
#     *   Yesterday
#     *   last + duration (e.g., last month, last week)
#     *   duration + ago (e.g., a week ago, 10 years ago)
#     *   in + year (e.g., in 2002)
#     *   the other day (منذ بضعة أيام)
#
# *   **Notes (الحــــــظ)**
#     *   **With frequency adverbs:** Used with the same frequency adverbs as the present tense when the action was in the past.
#         *   Example: He always visited us when he was young.
#     *   **With 'for':** Can be used if the action lasted for a specific period in the past.
#         *   Example: My father went to a primary school for 6 years.
#     *   **Use of 'was/were':** Used when the verb is originally "to be" in affirmative, negative, and interrogative sentences.
#         *   Affirmative: I was at school last Monday.
#         *   Negative: I wasn’t at school last Monday.
#         *   Interrogative: Were you at school last Monday?
#     *   **Use of 'had':** Used when the verb is originally "to have" (meaning "owned" or "possessed").
#         *   Affirmative: I had a nice bike when I was young.
#         *   Negative: In the negative, use 'didn’t have'.
#             *   Example: I didn’t have a bike when I was young.
#
# *   **Other Uses**
#     *   **After 'I’d rather' + subject:** Expresses a preference about the present.
#         *   Example: I’d rather you went to school today.
#     *   **In the 'if' clause of Conditional Type 2:** Expresses an impossible or unlikely event in the present or future (imagination/assumption).
#         *   Example: If I discovered a new planet, I’d give it my name.
#     *   **After 'wish' and 'if only':** Expresses a wish or regret about the present, hoping for a different situation.
#         *   Example: I wish I lived near my school.
#     *   **After 'suppose/supposing':** For assuming something unlikely or untrue.
#         *   Example: Suppose you met the president, what would you ask him to do?
#     *   **After 'as if/as though':** To compare a person or thing to another, meaning "as if."
#         *   Example: Ahmed treats us as if he were a king.
#     *   **For an interrupting or short action with the Past Continuous:**
#         *   Example: While Ali was climbing the ladder, he fell down.
#     *   **For the second action when the first action was Past Perfect:**
#         *   Example: After he had booked the ticket, he took the train.
#     *   **After 'It’s time/It’s high time':**
#         *   Example: It’s time you went to bed.

# %% [markdown]
# ## Reduce

# %%
reduce_parser = PydanticOutputParser(pydantic_object=MainIdeas)

# %%
reduce_prompt = StagePrompt(
    system="Instructions:\n"
    "You are reducing sets of detailed concept maps, a concise yet comprehensive list of important concepts, generated by extracting concepts from a document and potentially combining subsets of them that are relevant to each other.\n"
    "The goal is to create a structured resource that fully captures the essence of the material for testing and teaching purposes.\n"
    "Your task is to:\n\n"
    "- Identify the most critical concepts from the detailed concept map.\n"
    "- Provide a full-sentence summary for each concept that explains its significance, its relationship to other concepts, and any relevant examples or applications.\n"
    "- Ensure that the summaries are clear, self-contained, and detailed enough to aid in understanding without requiring additional context.\n"
    "- If necessary, combine related concepts into a single summary. Some of the concept maps have broader headings that can be used to guide this process.\n"
    "Answer in the following format:\n"
    ""+reduce_parser.get_format_instructions().replace('{', '{{').replace('}', '}}'),

    human="Here is the detailed concept map:\n"
    "Context:\n"
    "{context}\n"
)

# %%
reduce_prmpt_tmplt = ChatPromptTemplate.from_messages(
    [
        ("system", reduce_prompt.system),
        ("human", reduce_prompt.human)
    ]
)

# %%
reduce_chain = reduce_prmpt_tmplt | llm | reduce_parser

# %%
reduce_output = reduce_chain.invoke({"context": combine_output})

# %%
reduce_output
# Out:
# MainIdeas(MainIdeas=[MainIdea(name='Past Simple Form', summary="The Past Simple tense is constructed in several forms: for affirmative sentences, it uses the subject followed by the past participle (V2), as in 'Dalia travelled to Aswan a week ago'; for interrogative sentences, it uses 'Did' + subject + infinitive or 'Wh-word' + 'did' + subject + infinitive, such as 'Did Maher invite you to the party last Friday?'; for negative sentences, it follows the structure subject + 'didn’t' + infinitive, like 'My son didn’t use mobile phones 10 years ago'; and in the passive voice, it uses object + 'was/were' + past participle, as demonstrated by 'The pyramids were built by the ancient Egyptians'."), MainIdea(name='Core Usage of Past Simple', summary="The Past Simple tense is primarily used to describe actions that were completed in the past, either with a clear time indicator (e.g., 'It rained heavily yesterday') or when the past context is evident without one (e.g., 'Graham Bell invented the telephone'). It is also employed to narrate a sequence of events in the past (e.g., 'Jehan wiped the table after dinner, took a shower and went to bed'), to express past habits that are no longer current (e.g., 'People in the past travelled on camels'), to provide specific details for events previously mentioned with the Present Perfect (e.g., 'I’ve hurt my leg. I fell off a ladder'), and to narrate events within stories."), MainIdea(name='Time Expressions for Past Simple', summary="Specific time expressions are crucial indicators for using the Past Simple tense, including 'yesterday,' 'last' followed by a duration (e.g., 'last month'), a duration followed by 'ago' (e.g., 'a week ago'), 'in' followed by a year (e.g., 'in 2002'), and 'the other day,' all of which help to pinpoint when a completed action occurred in the past."), MainIdea(name='Special Uses of Past Simple in Hypothetical and Conditional Contexts', summary="Beyond its primary function, the Past Simple is used in various specific grammatical constructions: after 'I’d rather' followed by a subject to express a preference for the present (e.g., 'I’d rather you went to school today'); in the 'if' clause of the second conditional to describe an impossible or unlikely event in the present or future (e.g., 'If I discovered a new planet, I’d give it my name'); after 'wish' and 'if only' to express wishes or regrets about a present situation (e.g., 'I wish I lived near my school'); after 'suppose/supposing' to assume something unlikely or unreal (e.g., 'Suppose you met the president'); after 'as if/as though' for comparisons (e.g., 'Ahmed treats us as if he were a king'); and after 'It’s time/It’s high time' followed by a subject to indicate that an action should already be happening (e.g., 'It’s time you went to bed')."), MainIdea(name='Past Simple with Adverbs of Frequency and Duration', summary="The Past Simple can be used with adverbs of frequency, such as 'always,' to describe recurring past habits (e.g., 'He always visited us when he was young'), and it can also be used with the preposition 'for' to specify the duration of an action that lasted for a particular period in the past (e.g., 'My father went to a primary school for 6 years'), providing additional context about the nature and length of past events."), MainIdea(name="Past Simple with 'To Be' and 'To Have' as Main Verbs", summary="When 'to be' acts as the main verb in the Past Simple, it takes the forms 'was' or 'were' for affirmative, negative, and interrogative sentences (e.g., 'I was at school last Monday,' 'I wasn’t at school last Monday,' 'Were you at school last Monday?'). Similarly, 'had' is used as the main verb for 'to have' or 'to possess' in the Past Simple (e.g., 'I had a nice bike when I was young'), with its negative form being 'didn’t have' (e.g., 'I didn’t have a bike when I was young')."), MainIdea(name='Past Simple in Relation to Other Tenses', summary="The Past Simple frequently interacts with other tenses to d ...

# %%
for i, c in enumerate(reduce_output.MainIdeas):
    print("Idea", i)
    print(c)
# Out:
# Idea 0
# name='Past Simple Form' summary="The Past Simple tense is constructed in several forms: for affirmative sentences, it uses the subject followed by the past participle (V2), as in 'Dalia travelled to Aswan a week ago'; for interrogative sentences, it uses 'Did' + subject + infinitive or 'Wh-word' + 'did' + subject + infinitive, such as 'Did Maher invite you to the party last Friday?'; for negative sentences, it follows the structure subject + 'didn’t' + infinitive, like 'My son didn’t use mobile phones 10 years ago'; and in the passive voice, it uses object + 'was/were' + past participle, as demonstrated by 'The pyramids were built by the ancient Egyptians'."
# Idea 1
# name='Core Usage of Past Simple' summary="The Past Simple tense is primarily used to describe actions that were completed in the past, either with a clear time indicator (e.g., 'It rained heavily yesterday') or when the past context is evident without one (e.g., 'Graham Bell invented the telephone'). It is also employed to narrate a sequence of events in the past (e.g., 'Jehan wiped the table after dinner, took a shower and went to bed'), to express past habits that are no longer current (e.g., 'People in the past travelled on camels'), to provide specific details for events previously mentioned with the Present Perfect (e.g., 'I’ve hurt my leg. I fell off a ladder'), and to narrate events within stories."
# Idea 2
# name='Time Expressions for Past Simple' summary="Specific time expressions are crucial indicators for using the Past Simple tense, including 'yesterday,' 'last' followed by a duration (e.g., 'last month'), a duration followed by 'ago' (e.g., 'a week ago'), 'in' followed by a year (e.g., 'in 2002'), and 'the other day,' all of which help to pinpoint when a completed action occurred in the past."
# Idea 3
# name='Special Uses of Past Simple in Hypothetical and Conditional Contexts' summary="Beyond its primary function, the Past Simple is used in various specific grammatical constructions: after 'I’d rather' followed by a subject to express a preference for the present (e.g., 'I’d rather you went to school today'); in the 'if' clause of the second conditional to describe an impossible or unlikely event in the present or future (e.g., 'If I discovered a new planet, I’d give it my name'); after 'wish' and 'if only' to express wishes or regrets about a present situation (e.g., 'I wish I lived near my school'); after 'suppose/supposing' to assume something unlikely or unreal (e.g., 'Suppose you met the president'); after 'as if/as though' for comparisons (e.g., 'Ahmed treats us as if he were a king'); and after 'It’s time/It’s high time' followed by a subject to indicate that an action should already be happening (e.g., 'It’s time you went to bed')."
# Idea 4
# name='Past Simple with Adverbs of Frequency and Duration' summary="The Past Simple can be used with adverbs of frequency, such as 'always,' to describe recurring past habits (e.g., 'He always visited us when he was young'), and it can also be used with the preposition 'for' to specify the duration of an action that lasted for a particular period in the past (e.g., 'My father went to a primary school for 6 years'), providing additional context about the nature and length of past events."
# Idea 5
# name="Past Simple with 'To Be' and 'To Have' as Main Verbs" summary="When 'to be' acts as the main verb in the Past Simple, it takes the forms 'was' or 'were' for affirmative, negative, and interrogative sentences (e.g., 'I was at school last Monday,' 'I wasn’t at school last Monday,' 'Were you at school last Monday?'). Similarly, 'had' is used as the main verb for 'to have' or 'to possess' in the Past Simple (e.g., 'I had a nice bike when I was young'), with its negative form being 'didn’t have' (e.g., 'I didn’t have a bike when I was young')."
# Idea 6
# name='Past Simple in Relation to Other Tenses' summary="The Past Simple frequently interacts with other tenses to describe sequences or concurrent events: it is used for a short or interrupting action that occurs during another ongoing action expressed in the Past Continuous (e.g., 'While Ali was climbing the ladder, he fell down'), and it represents the second event in a sequence where the first event was completed using the Past Perfect (e.g., 'After he had booked the ticket, he took the train'), illustrating its role in establishing chronological order and relationships between past actions."
# Idea 7
# name='Past Continuous Form' summary="The Past Continuous tense is formed using 'was/were' + the present participle (verb-ing): for affirmative sentences, it is subject + 'was/were' + verb-ing (e.g., 'I was having dinner when you phoned me'); for negative sentences, it is subject + 'wasn’t/weren’t' + verb-ing (e.g., 'I wasn’t sleeping when my father came'); for interrogative sentences, it uses 'Wh-word' + 'was/were' + subject + verb-ing or 'Was/Were' + subject + verb-ing (e.g., 'What were you doing yesterday at five p.m.?'); and in the passive voice, it follows the structure object + 'was/were' + 'being' + past participle (e.g., 'While my hair was being cut, the light went out')."
# Idea 8
# name='Usage of Past Continuous' summary="The Past Continuous tense is used to describe an action that was in progress at a specific moment or over a period in the past, often serving as background for another, shorter action expressed in the Past Simple (e.g., 'I was having dinner when you phoned me') or to describe two or more actions happening simultaneously in the past, emphasizing their duration or continuity rather than their completion."

# %% [markdown]
# # **Ranking**

# %%
class Ranking(BaseModel):
    ranking : List[int] = Field(..., description='Rank corresponding to each idea')

# %%
rank_parser = PydanticOutputParser(pydantic_object=Ranking)

# %%
print(rank_parser.get_format_instructions().replace('{', '{{').replace('}', '}}'))
# Out:
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {{"properties": {{"foo": {{"title": "Foo", "description": "a list of strings", "type": "array", "items": {{"type": "string"}}}}}}, "required": ["foo"]}}
# the object {{"foo": ["bar", "baz"]}} is a well-formatted instance of the schema. The object {{"properties": {{"foo": ["bar", "baz"]}}}} is not well-formatted.
#
# Here is the output schema:
# ```
# {{"properties": {{"ranking": {{"description": "Rank corresponding to each idea", "items": {{"type": "integer"}}, "title": "Ranking", "type": "array"}}}}, "required": ["ranking"]}}
# ```

# %%
rank_prompt = StagePrompt(
    system="Instructions:\n"
    "Given the following groups of main ideas extracted from a text, rank them in order of importance, with the most important main idea receiving a rank of 1 and lower ranks for less important ideas.\n"
    "Focus on the most important aspects of the text and the main ideas that are critical to understanding the material.\n"
    "While sometimes important, background information or less critical ideas should be ranked lower.\n"
    "When ranking:\n\n"
    "- Assign a unique number to each main idea, starting from 1.\n"
    "- Ensure that the most important main idea is ranked first.\n"
    "- Rank the main ideas based on their relevance and significance.\n"
    "- If necessary, combine related concepts into a single summary. Some of the concept maps have broader headings that can be used to guide this process.\n\n"
    "Example:\n"
    "Input: [Main Idea 1, Main Idea 2, Main Idea 3]\n"
    "Output: [2, 1, 3]\n\n"
    "Respond in the following fromat"
    ""+rank_parser.get_format_instructions().replace('{', '{{').replace('}', '}}'),
    
    human= "Main Ideas:\n"
    "{context}",
)

# %%
rank_prmpt_tmplt = ChatPromptTemplate.from_messages(
    [
        ("system", rank_prompt.system),
        ("human", rank_prompt.human)
    ]
)

# %%
rank_chain = rank_prmpt_tmplt | llm | rank_parser

# %%
rank_output = rank_chain.invoke({"context": reduce_output})
rank_output
# Out:
# Ranking(ranking=[1, 3, 2, 4, 5, 6, 7, 8, 9])

# %%
def reranked(ideas, ranking):
    assert len(ideas) == len(ranking), "ideas and ranking lists are not of the same length"
    ranked_ideas = [None] * len(ranking)
    for idea, rank in zip(ideas, ranking):
        ranked_ideas[rank-1] = idea

    return ranked_ideas

# %% [markdown]
# # **Running Example**

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
with open('content/01 - u1_Past Simple.txt') as f:
    doc = f.read()

splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=40)
chunks = splitter.split_text(doc)
print(f"Extracted {len(chunks)} chunks")
print(chunks)
# Out:
# Extracted 7 chunks
# ['Past Simple  الماضى البسيط1\nForm\nSubj. + التصريف الثانى للفعل\n •Dalia travelled to Aswan a week ago.\n• Yahya Haqqi wrote many interesting short stories.\nInterrogative\nDid + subj. + inf.?/Wh-word + did + subj. + inf.?\n• Did Maher invite you to the party last Friday?\n• What did you study last night?\nNegative\nSubj. + didn’t + inf.\n• My son didn’t use mobile phones 10 years ago. \nPassive \nObj. + was/were + P.P.\n• The pyramids were built by the ancient Egyptians.', '.حدث تم وانتهى فى الماضى ويوجد ما يدل عليه من كلمات It rained heavily yesterday.\n1\n .)حدث تم وانتهى فى الماضى وال يوجد ما يدل عليه من كلمات (الماضى البديهى\n Graham Bell invented the telephone.\n2\n.لتتابع األحداث فى الماضى\n Jehan wiped the table after dinner, took a shower and went to bed.\n.)عادات الماضى (وقبل أن تكون عادات فى الماضى كانت عادات فى المضارع\n People in the past travelled on camels.\n When I was on holiday, I went to the beach every day.\n3', '3\n . لعادات الماضى وليس لحدث منذ زمن قريب ولم يكن عادةused to نستخدم\n When I was young, I used to play (played) in the street. ✓\n He used to go to the sports club three times last week. ✗\n He went to the sports club three times last week. ✓\n4\n .لتفاصيل األحداث مع المضارع التام I’ve hurt my leg. I fell off a ladder.\n5\n .لسرد أحداث القصص\n Once, we saw a man in ... .\n He sat down and ordered a coffee.\n6\n:ويستخدم الماضى البسيط مع الكلمات والتعبيرات الزمنية اآلتية', 'Yesterday, last +  مدة, مدة+ ago, in 2002, the other day / منذ بضعة أيامmonth, etc.\n7\nUsage\nاالستخدام\nW\na\nt\nc\nh\n \na\n \nv\ni\nd\ne\no\nStudy\nStudy\nUnits 1  & 2\nPart 1\n20\nالحــــــظ\n.١ يستخدم مع نفس ظروف التكرار التى كانت تستخدم عندما كان الفعل مضارعـًا\n He always visited us when he was young.\n. مع الماضى البسيط إذا كان الفعل قد استغرق مدة محددة فى الماضىfor ٢ يمكن استخدام\n My father went to a primary school for 6 years.', ': مع الماضى إذا كان الفعل أصليا بمعنى «كان» فى الجملة الخبرية المثبتة والمنفية والسؤال كاآلتىwas/were ٣ نستخدم\n I was at school last Monday. \n \n \n I wasn’t at school last Monday.\n Were you at school last Monday?\n.» مع الماضى إذا كان الفعل أصليـًّا بمعنى «كان يملك» أو «امتلكhad  نستخدم4\n I had a nice bike when I was young.\n I didn’t have a bike when I was young. \ndidn’t have وفى النفى نستخدم\nOther uses\n:يستخدم الماضى البسيط\n’ إذا جاء بعدها فاعل، وتعبر عن المضارع.d rather ١ مع', 'I’d rather you went to school today.\n.) لبيان استحالة أو عدم احتمال حدوث فعل فى المضارع أو المستقبل (تخيل أو افتراضif ٢ فى فعل شرط الحالة الثانية من\n If I discovered a new planet, I’d give it my name.\n . للتمنى أو الندم فى المضارع بخصوص موقف نتمنى أن يكون مختلفًاif only وwish ٣ بعد\n I wish I lived near my school. \n. الفتراض حدوث شىء وهو غير محتمل أو حقيقىsuppose/supposing  بعد4\n Suppose you met the president, what would you ask him to do?', '. بمعنى كما لو لتشبيه شخص بشخص أو شىء بشىءas if/as though  بعد5\n Ahmed treats us as if he were a king.\n.) للحدث القاطع أو القصير مع حدث آخر مستمر (مع الماضى المستمر6\n While Ali was climbing the ladder, he fell down.\n. للحدث الثانى عندما يكون الحدث األول ماضيـًا تامـًّا7\n After he had booked the ticket, he took the train.\n It’s time/It’s high time  بعد8\n It’s time you went to bed.']

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash-lite", # up to 30 requests per minute allowed
    temperature=0,
    max_tokens=None,
    timeout=None,
)

# %%
import asyncio

async def process_chunk(chunk):
    ideas = await extrct_chain.ainvoke(input={'context': chunk})
    return ideas.content

# Process chunks in parallel
async def process_all_chunks(chunks):
    tasks = [process_chunk(chunk) for chunk in chunks]
    results = await asyncio.gather(*tasks)
    return "".join(results)

# Run the async function
collected_ideas = await process_all_chunks(chunks)

# %%
combined = combine_chain.invoke(input={'context':collected_ideas})
reduced = reduce_chain.invoke(input={'context':combined})
ranked = rank_chain.invoke(input={'context':reduced})

# %%
reranked(ideas= reduced.MainIdeas, ranking=ranked.ranking)
# Out:
# [MainIdea(name='Past Simple Tense', summary='The Past Simple tense is used to describe completed actions in the past. It is formed with the subject and the second form of the verb, such as "Dalia travelled to Aswan." Questions are formed using "Did + subject + infinitive," like "Did Maher invite you?" Negatives use "didn’t + infinitive," as in "My son didn’t use mobile phones." The passive voice uses "was/were + Past Participle," for example, "The pyramids were built." It is used to provide details of events with the present perfect tense, for storytelling, with specific time expressions (e.g., yesterday, last week, ago), and with frequency adverbs. It can also be used if the action took a specific duration in the past. Examples of time expressions include "yesterday," "last week," "a week ago," and "in 2002."'),
#  MainIdea(name='Past Tense Events', summary='Past tense events describe actions that occurred and finished in the past. These events can be explicitly marked with time indicators, such as "It rained heavily yesterday," or implied, such as "Graham Bell invented the telephone." Sequencing of past events involves actions that occurred in a specific order, for example, "Jehan wiped the table after dinner, took a shower and went to bed." Past habits refer to actions that were habitual in the past, often contrasting with present habits, such as "People in the past travelled on camels." The past simple is used to describe these events and habits.'),
#  MainIdea(name='Used to', summary='"Used to" is employed to discuss past habits, not recent events. For example, "When I was young, I used to play in the street." It is used to describe actions that were habitual in the past, contrasting with present habits. The correct usage is exemplified by "He went to the sports club three times last week," while the incorrect usage would be "He used to go to the sports club three times last week."'),
#  MainIdea(name='Using "was/were" and "had" in the Past Tense', summary='"Was/were" is used when the verb is original, meaning "was" in affirmative, negative, and interrogative declarative sentences, such as "I was at school last Monday." "Had" is used when the verb is original, meaning "had" or "owned," as in "I had a nice bike when I was young." The negative form of "had" is "didn’t have," as in "I didn’t have a bike when I was young."'),
#  MainIdea(name='Other Uses of the Simple Past Tense', summary='The simple past tense is used with "I\'d rather" when followed by a subject, expressing the present tense.'),
#  MainIdea(name='Conditional Sentences (Type 2)', summary='Conditional Sentences (Type 2) express the impossibility or unlikelihood of an action in the present or future, often used for imagination or supposition. The structure is "if + past simple, would + base form of the verb," as in "If I discovered a new planet, I’d give it my name."'),
#  MainIdea(name='"wish" and "if only"', summary='"Wish" and "if only" are used to express a wish or regret in the present about a situation we wish were different, such as "I wish I lived near my school."'),
#  MainIdea(name='"suppose/supposing"', summary='"Suppose/supposing" is used to suppose something that is unlikely or not real, as in "Suppose you met the president, what would you ask him to do?"'),
#  MainIdea(name='"as if/as though"', summary='"As if/as though" is used for comparison or to draw a resemblance between a person and another person or thing, such as "Ahmed treats us as if he were a king."'),
#  MainIdea(name='"While"', summary='"While" is used to connect a short or completed action with another ongoing action, typically with the past continuous tense, as in "While Ali was climbing the ladder, he fell down."'),
#  MainIdea(name='"After"', summary='"After" is used to indicate the second event when the first event is in the past perfect tense, as in "After he had booked the ticket, he took the train."'),
#  MainIdea(name='"It’s time/It’s high time"', summary='"It’s time/It’s high time" is used to express that it is time for something to happen, such as "It’s time you went to bed."')]
